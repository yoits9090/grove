# %% [markdown]
# # GROVE reproducibility notebook
# Clone a pinned commit, run correctness, and collect a smoke benchmark. Change `COMMIT` explicitly for every experiment.

# %%
REPO = "https://github.com/yoits9090/grove.git"
COMMIT = "b1a2b2d"  # replace with an explicit commit SHA
# !git clone $REPO grove-colab
# %cd grove-colab
# !git checkout $COMMIT
# %pip install -e .
# !uv --version || true

# %%
# !python -m pytest -q
# !python benchmarks/bench.py --nodes 200 --reads 100 --seed 7
